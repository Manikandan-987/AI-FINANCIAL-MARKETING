# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ai_financial_market_daily_realistic_synthetic.csv")

# %%
df
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
df.head()
# Out:
#          Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0  2015-01-01  OpenAI                 5.92               0.63
# 1  2015-01-02  OpenAI                 5.41               1.81
# 2  2015-01-03  OpenAI                 4.50               0.61
# 3  2015-01-04  OpenAI                 5.45               0.95
# 4  2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
df.tail()
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 10954               417.68   NaN           -0.66
# 10955               411.86   NaN           -0.57
# 10956               415.54   NaN           -0.52
# 10957               416.03   NaN            0.22
# 10958               417.04   NaN           -0.16

# %%
df.shape
# Out:
# (10959, 7)

# %%
df.size
# Out:
# 76713

# %%
df.columns
# Out:
# Index(['Date', 'Company', 'R&D_Spending_USD_Mn', 'AI_Revenue_USD_Mn',
#        'AI_Revenue_Growth_%', 'Event', 'Stock_Impact_%'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                    object
# Company                 object
# R&D_Spending_USD_Mn    float64
# AI_Revenue_USD_Mn      float64
# AI_Revenue_Growth_%    float64
# Event                   object
# Stock_Impact_%         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  datetime64[ns]
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 599.4+ KB

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
df['Company'].unique()
# Out:
# array(['OpenAI', 'Google', 'Meta'], dtype=object)

# %%
df['Year']=df['Date'].dt.year

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
df
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0                   -36.82   NaN           -0.36  2015
# 1                    80.59   NaN            0.41  2015
# ...

# %%
df[df["Event"]=='GPT-4 release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2994 2023-03-14  OpenAI                 7.78               4.05
#
#       AI_Revenue_Growth_%          Event  Stock_Impact_%  Year
# 2994               304.57  GPT-4 release            15.2  2023

# %%
df.isnull().sum()
# Out:
# Date                       0
# Company                    0
# R&D_Spending_USD_Mn        0
# AI_Revenue_USD_Mn          0
# AI_Revenue_Growth_%        0
# Event                  10726
# Stock_Impact_%             0
# Year                       0
# dtype: int64

# %% [raw]
# HOW MUCH AMOUNT THE COMPANIES SPENT R &D ?

# %%
df1=df.groupby('Company')['R&D_Spending_USD_Mn'].sum()/1000
df1
# Out:
# Company
# Google    423.34114
# Meta      264.53307
# OpenAI     26.48277
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
plt.bar(df1.index,df1.values,color = ['cyan','black','magenta'],width=0.5)
plt.title("R & D SPENDING BY THIS COMPANIES")
plt.xlabel("Company")
plt.ylabel("Amount in USO_$Bn")
plt.show()

# %% [raw]
# REVENUE EARNED BY THE COMPANIES?

# %%
df2=df.groupby('Company')['AI_Revenue_USD_Mn'].sum()/1000
df2
# Out:
# Company
# Google    284.49838
# Meta      189.62182
# OpenAI      9.46289
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
plt.bar(df2.index,df2.values,color = ['cyan','black','magenta'],width=0.5)
plt.title("REVENUE EARNED BY THE COMPANIES")
plt.xlabel("Company")
plt.ylabel("Amount in USD_$Bn")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.bar(df1.index,df1.values,color = ['cyan','black','magenta'],width=0.5)
plt.title("R & D SPENDING BY THIS COMPANIES")
plt.xlabel("Company")
plt.ylabel("Amount in USO_$Bn")
plt.subplot(1,2,2)
plt.bar(df2.index,df2.values,color = ['cyan','black','magenta'],width=0.5)
plt.title("REVENUE EARNED BY THE COMPANIES")
plt.xlabel("Company")
plt.ylabel("Amount in USD_$Bn")
plt.show()

# %% [raw]
# DATE-WISE IMPACT ON THE STOCK

# %%
plt.figure(figsize=(10,2))
plt.plot(df['Date'],df['Stock_Impact_%'],color='green')
plt.title("CHANGE IN STOCK VALUE")
plt.xlabel("Date('Year')")
plt.ylabel("Stock_impact_%")
plt.show()

# %% [raw]
# EVENTS WHEN MAXIMUM STOCK IMPACT WAS OBSERVED

# %%
df3=df[df['Company']=='OpenAI']
df3
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0    2015-01-01  OpenAI                 5.92               0.63
# 1    2015-01-02  OpenAI                 5.41               1.81
# 2    2015-01-03  OpenAI                 4.50               0.61
# 3    2015-01-04  OpenAI                 5.45               0.95
# 4    2015-01-05  OpenAI                 3.40               1.48
# ...         ...     ...                  ...                ...
# 3648 2024-12-27  OpenAI                10.06               4.71
# 3649 2024-12-28  OpenAI                 9.67               5.32
# 3650 2024-12-29  OpenAI                 9.17               5.46
# 3651 2024-12-30  OpenAI                10.36               6.31
# 3652 2024-12-31  OpenAI                10.24               4.92
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0                  -36.82   NaN           -0.36  2015
# 1                   80.59   NaN            0.41  2015
# ...

# %%
df4=df[df['Company']=='Google']
df4
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3653 2015-01-01  Google                79.89              30.19
# 3654 2015-01-02  Google                78.99              30.44
# 3655 2015-01-03  Google                79.20              30.46
# 3656 2015-01-04  Google                79.59              30.55
# 3657 2015-01-05  Google                81.50              30.59
# ...         ...     ...                  ...                ...
# 7301 2024-12-27  Google               162.16             155.36
# 7302 2024-12-28  Google               159.69             154.47
# 7303 2024-12-29  Google               161.69             154.59
# 7304 2024-12-30  Google               158.48             155.05
# 7305 2024-12-31  Google               159.48             154.77
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 3653                 0.64   NaN           -0.02  2015
# 3654                 1.47   NaN           -0.98  2015
# ...

# %%
df5=df[df['Company']=='Meta']
df5
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 7306  2015-01-01    Meta                50.39              18.95
# 7307  2015-01-02    Meta                49.80              19.77
# 7308  2015-01-03    Meta                49.09              19.96
# 7309  2015-01-04    Meta                50.66              20.48
# 7310  2015-01-05    Meta                51.36              19.84
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 7306                 -5.23   NaN           -0.42  2015
# 7307                 -1.16   NaN            0.63  2015
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(df3['Date'],df3['Stock_Impact_%'],color='m')
plt.title("CHANGE IN STOCK VALUE OF OPEN AI")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df4['Date'],df4['Stock_Impact_%'],color='c')
plt.title("CHANGE IN STOCK VALUE OF GOOGLE")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df5['Date'],df5['Stock_Impact_%'],color='black')
plt.title("CHANGE IN STOCK VALUE OF META")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %% [raw]
# AI REVENUE GROWTH OF THE COMPANIES

# %%
sns.scatterplot(x='Date',y='AI_Revenue_Growth_%',data=df,hue='Company')
plt.show()

# %%
plt.plot(df3['Date'],df3["AI_Revenue_Growth_%"],color='m')
plt.title("CHANGE IN STOCK VALUE OF META")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")

plt.show()

# %%
plt.plot(df4['Date'],df4["AI_Revenue_Growth_%"],color='c')
plt.title("CHANGE IN STOCK VALUE OF META")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")

plt.show()

# %%
plt.plot(df5['Date'],df5["AI_Revenue_Growth_%"],color='orange')
plt.title("CHANGE IN STOCK VALUE OF META")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")

plt.show()

# %% [raw]
# CORRELATION BETWEEN THE COLUMNS

# %%
df.corr(numeric_only=True)
# Out:
#                      R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# R&D_Spending_USD_Mn             1.000000           0.935030
# AI_Revenue_USD_Mn               0.935030           1.000000
# AI_Revenue_Growth_%             0.291245           0.530128
# Stock_Impact_%                 -0.004628          -0.000017
# Year                            0.297701           0.526478
#
#                      AI_Revenue_Growth_%  Stock_Impact_%      Year
# R&D_Spending_USD_Mn             0.291245       -0.004628  0.297701
# AI_Revenue_USD_Mn               0.530128       -0.000017  0.526478
# AI_Revenue_Growth_%             1.000000        0.020937  0.952199
# Stock_Impact_%                  0.020937        1.000000  0.016525
# Year                            0.952199        0.016525  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [raw]
# EXPENDITURE VS REVENUE YEAR-BY-YEAR

# %%
df6=df.groupby('Year')['R&D_Spending_USD_Mn'].sum()
df6
# Out:
# Year
# 2015    49304.23
# 2016    53349.94
# 2017    57475.12
# 2018    62002.16
# 2019    67071.51
# 2020    72602.53
# 2021    78207.32
# 2022    84390.17
# 2023    91193.92
# 2024    98760.08
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
plt.plot(df6.index,df6.values,color='r')
plt.title("COMBINED R & D SPENDING YEAR-BY-YEAR")
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.show()

# %%
df7=df.groupby('Year')['AI_Revenue_USD_Mn'].sum()
df7
# Out:
# Year
# 2015    18623.21
# 2016    22361.20
# 2017    26776.80
# 2018    32164.44
# 2019    38580.32
# 2020    46456.19
# 2021    55591.14
# 2022    66674.24
# 2023    80041.64
# 2024    96313.91
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
plt.plot(df7.index,df7.values,color='green')
plt.title("COMBINED R & D SPENDING YEAR-BY-YEAR")
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.show()

# %%
plt.plot(df6.index,df6.values,color='r')
plt.plot(df7.index,df7.values,color='green')
plt.title("COMBINED EXPENDITURE VS REVENUE ")
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.legend(['Expenditure','Revenue'])
plt.show()

# %%
sns.pairplot(df)# to show relationship between columns

# %% [raw]
# EVENT IMPACT ANALYSICS

# %%
df.Event.value_counts()
# Out:
# Event
# AI speech recognition release      37
# AI-powered search update           32
# AI Ads Optimization upgrade        32
# AI partnership deal                32
# AI Video Recommendation upgrade    29
# Cloud AI launch                    27
# AI ethics policy update            27
# TensorFlow open-source release      1
# LLaMA 2 release                     1
# LLaMA 1 release                     1
# Gemini AI release                   1
# Bard chatbot launch                 1
# MUM Search Model launch             1
# BERT for Search launch              1
# AlphaGo beats Lee Sedol             1
# ChatGPT (GPT-3.5) launch            1
# GPT-5 release (predicted)           1
# GPT-4 release                       1
# DALL·E 2 release                    1
# Codex release                       1
# GPT-3 release                       1
# GPT-2 release                       1
# GPT-1 release                       1
# LLaMA 3 release (predicted)         1
# Name: count, dtype: int64

# %%
df[df.Event =="TensorFlow open-source release"]#checking particular event
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3965 2015-11-09  Google                79.62              29.84
#
#       AI_Revenue_Growth_%                           Event  Stock_Impact_%  \
# 3965                -0.53  TensorFlow open-source release             4.5
#
#       Year
# 3965  2015

# %%
df8=df.loc[3955:3975]
df8
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3955 2015-10-30  Google                80.33              29.87
# 3956 2015-10-31  Google                79.53              30.30
# 3957 2015-11-01  Google                80.37              29.86
# 3958 2015-11-02  Google                77.89              29.97
# 3959 2015-11-03  Google                81.00              29.43
# 3960 2015-11-04  Google                80.70              29.71
# 3961 2015-11-05  Google                78.31              30.25
# 3962 2015-11-06  Google                79.08              29.84
# 3963 2015-11-07  Google                79.65              30.34
# 3964 2015-11-08  Google                79.63              29.74
# 3965 2015-11-09  Google                79.62              29.84
# 3966 2015-11-10  Google                81.65              29.44
# 3967 2015-11-11  Google                78.67              30.02
# 3968 2015-11-12  Google                81.43              29.56
# ...

# %%
plt.figure(figsize=(10,4))
plt.plot(df8['Date'],df8['Stock_Impact_%'],color='c')
plt.title("COMPARISON BEFORE AND AFTER RELEASE OF TENSOR FLOW")
plt.xlabel("Date")
plt.ylabel("Change in stock %")
plt.show()

# %%
df9=df.loc[2984:3004]
df9
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2984 2023-03-04  OpenAI                10.59               4.26
# 2985 2023-03-05  OpenAI                 8.24               3.58
# 2986 2023-03-06  OpenAI                 9.32               4.21
# 2987 2023-03-07  OpenAI                 8.52               4.13
# 2988 2023-03-08  OpenAI                 8.90               3.63
# 2989 2023-03-09  OpenAI                 8.44               4.64
# 2990 2023-03-10  OpenAI                 9.55               4.83
# 2991 2023-03-11  OpenAI                 8.34               3.95
# 2992 2023-03-12  OpenAI                 8.71               3.57
# 2993 2023-03-13  OpenAI                10.61               5.19
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2995 2023-03-15  OpenAI                12.31               4.44
# 2996 2023-03-16  OpenAI                10.60               4.64
# 2997 2023-03-17  OpenAI                10.77               4.78
# ...

# %%
df[df.Event =="GPT-4 release"]
df
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0                   -36.82   NaN           -0.36  2015
# 1                    80.59   NaN            0.41  2015
# ...

# %%
plt.figure(figsize=(10,4))
plt.plot(df9['Date'],df9['Stock_Impact_%'],color='m')
plt.title("COMPARISON BEFORE AND AFTER RELEASE OF CHATGPT 4")
plt.xlabel("Date")
plt.ylabel("Change in stock %")
plt.show()

# %%
df.groupby('Company')['Stock_Impact_%'].mean()*100
# Out:
# Company
# Google    2.620860
# Meta      0.976184
# OpenAI    4.070901
# Name: Stock_Impact_%, dtype: float64

# %%
df.groupby('Company')['R&D_Spending_USD_Mn'].mean()
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
df.groupby('Company')['Stock_Impact_%'].max()
# Out:
# Company
# Google     6.2
# Meta       7.4
# OpenAI    18.5
# Name: Stock_Impact_%, dtype: float64

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %% [raw]
# CHANGE IN THE INDEX YEAR AND COMPANY

# %%
df10=df.groupby(['Year','Company'])['Stock_Impact_%'].max()
df10
# Out:
# Year  Company
# 2015  Google      4.96
#       Meta        4.80
#       OpenAI      3.92
# 2016  Google      6.20
#       Meta        2.14
#       OpenAI      4.66
# 2017  Google      4.42
#       Meta        4.21
#       OpenAI      4.63
# 2018  Google      1.97
#       Meta        4.54
#       OpenAI      4.94
# 2019  Google      3.20
#       Meta        1.86
#       OpenAI      4.20
# 2020  Google      4.18
#       Meta        4.86
#       OpenAI      8.50
# 2021  Google      4.10
#       Meta        4.80
#       OpenAI      7.20
# 2022  Google      4.88
#       Meta        3.98
#       OpenAI     12.00
# 2023  Google      5.80
#       Meta        6.80
#       OpenAI     15.20
# 2024  Google      2.89
#       Meta        7.40
#       OpenAI     18.50
# Name: Stock_Impact_%, dtype: float64

# %%
df10.plot(kind='barh',color=['r','black','m'])
plt.title("CHNAGE INDEX")
plt.show()

# %%
df.to_csv("ai.csv",index=False)
